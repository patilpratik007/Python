# %% [markdown]
# ## file handling

# %% [markdown]
# ![file%20handling%201.png](attachment:file%20handling%201.png)

# %%
f= open ("D:\Python files\sample.txt", "r")
print(f.read())

# %%
f= open ("D:\Python files\sample.txt","r")
print(f.read(5)) ## read first five character

# %%
f= open ("D:\Python files\sample.txt","r")
print(f.readline()) ## read 1st line

# %%
f= open ("D:\Python files\sample.txt","r")
print(f.readline()) 
print(f.readline())## read 1st two line

# %%
f= open ("D:\Python files\sample.txt","r")
for x in f: ## to read file line by line 
    print(x)

# %%
## append add text at end of existing file 
f= open ("D:\Python files\sample.txt","a")
print(f.write(" Best Luck!!"))

# %%
f= open ("D:\Python files\sample.txt","r")
for x in f: ## to read file line by line 
    print(x)

# %%
## write- overwrites mentioned text 
f= open ("D:\Python files\sample2.txt","w")
print(f.write(" Thank you"))

# %%
f= open ("D:\Python files\sample2.txt","r")
for x in f: ## to read file line by line 
    print(x)

# %%
## delete file 
f.close()
import os
os.remove("D:\Python files\sample2.txt")
